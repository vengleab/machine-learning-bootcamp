# %% [markdown]
# # Framework for machine learning project
# **1 Problem definition**
#
# => What problem we try to solve, whether it is classification problem or regression problem
#
# **2. Data**
#
# => What data we have?
#
# **3. Evaluation**
#
# => What define success/
#
# **4. Feature**
#
# => What feature should we model
#
# **5. Model**
#
# => What kind of model should we use
#
#
# **6. Experiments**
#
# => What have we tried/ what else can we try

# %% [markdown]
# ![image.png](attachment:ced41aef-3001-4ead-9524-dba8f3058b0c.png)
